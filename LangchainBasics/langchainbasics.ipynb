# %% [markdown]
# ### Langchain

# %% [markdown]
# Simple LLM calls with streaming
# Dynamic prompt templates(translation app)
# Building chains (story generator with analysis)
# Conversatinal Q&A assistant with memory
# Tool integration (calculate & weather)

# %%
import langchain

# %%
import os
#uv add -r requirements.txt
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Ex 1:Simple LLM Call with streaming
